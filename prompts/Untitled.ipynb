# %%
import os
import json
import pandas as pd
from rouge_score import rouge_scorer
from bert_score import score as bert_score
from tqdm import tqdm

# Path to folder with *_results.json files
RESULTS_FOLDER = "./"
OUTPUT_FOLDER = "auto_eval_results"
os.makedirs(OUTPUT_FOLDER, exist_ok=True)

# Load all model result files
def load_model_outputs(folder):
    data = {}
    for file in os.listdir(folder):
        if file.endswith("_results.json"):
            model_name = file.replace("ollama_", "").replace("_results.json", "")
            with open(os.path.join(folder, file)) as f:
                data[model_name] = json.load(f)
    return data

# Compute BERTScore & ROUGE
def evaluate_model_outputs(data):
    scorer = rouge_scorer.RougeScorer(['rougeL'], use_stemmer=True)
    results = []

    for model, entries in tqdm(data.items(), desc="Evaluating models"):
        hyps = []
        refs = []
        meta = []

        for entry in entries:
            hyp = entry.get("response", "").strip()
            ref = entry.get("reference", "").strip()

            if not hyp or not ref:
                continue

            hyps.append(hyp)
            refs.append(ref)
            meta.append({
                "id": entry["id"],
                "condition": entry["condition"],
                "model": model,
                "response": hyp,
                "reference": ref,
            })

        # BERTScore
        P, R, F1 = bert_score(hyps, refs, lang="en", verbose=True)
        f1_scores = F1.tolist()

        # ROUGE-L
        rouge_scores = [scorer.score(ref, hyp)['rougeL'].fmeasure for hyp, ref in zip(hyps, refs)]

        # Combine all
        for i, row in enumerate(meta):
            row["bertscore_f1"] = f1_scores[i]
            row["rougeL_f1"] = rouge_scores[i]
            results.append(row)

        # Save per-model CSV
        df = pd.DataFrame(results)
        model_file = os.path.join(OUTPUT_FOLDER, f"{model}_auto_eval.csv")
        df.to_csv(model_file, index=False)
        print(f"✅ Saved: {model_file}")

    return pd.DataFrame(results)

# === Main ===
if __name__ == "__main__":
    data = load_model_outputs(RESULTS_FOLDER)
    all_results_df = evaluate_model_outputs(data)
    all_results_df.to_csv(os.path.join(OUTPUT_FOLDER, "all_models_auto_eval.csv"), index=False)
    print("🏁 Done. Combined results saved to 'all_models_auto_eval.csv'")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 5
#       3 import pandas as pd
#       4 from rouge_score import rouge_scorer
# ----> 5 from bert_score import score as bert_score
#       6 from tqdm import tqdm
#       8 # Path to folder with *_results.json files
#
# ModuleNotFoundError: No module named 'bert_score'

# %%
pip install bert_score
# Out:
# WARNING: Ignoring invalid distribution ~uggingface-hub (/opt/nlp-env/lib/python3.11/site-packages)
# WARNING: Ignoring invalid distribution ~riton (/opt/nlp-env/lib/python3.11/site-packages)
# WARNING: Ignoring invalid distribution ~valuate (/opt/nlp-env/lib/python3.11/site-packages)
# WARNING: Ignoring invalid distribution ~orch (/opt/nlp-env/lib/python3.11/site-packages)
# WARNING: Ignoring invalid distribution ~uggingface-hub (/opt/nlp-env/lib/python3.11/site-packages)
# WARNING: Ignoring invalid distribution ~riton (/opt/nlp-env/lib/python3.11/site-packages)
# WARNING: Ignoring invalid distribution ~valuate (/opt/nlp-env/lib/python3.11/site-packages)
# WARNING: Ignoring invalid distribution ~orch (/opt/nlp-env/lib/python3.11/site-packages)
# WARNING: Ignoring invalid distribution ~orchvision (/opt/nlp-env/lib/python3.11/site-packages)
# WARNING: Ignoring invalid distribution ~penai (/opt/nlp-env/lib/python3.11/site-packages)
# WARNING: Ignoring invalid distribution ~ytorch-triton-rocm (/opt/nlp-env/lib/python3.11/site-packages)
# WARNING: Ignoring invalid distribution ~ython-dateutil (/opt/nlp-env/lib/python3.11/site-packages)
# WARNING: Ignoring invalid distribution ~ix (/opt/nlp-env/lib/python3.11/site-packages)
# WARNING: Ignoring invalid distribution ~orchaudio (/opt/nlp-env/lib/python3.11/site-packages)
# Collecting bert_score
#   Using cached bert_score-0.3.13-py3-none-any.whl.metadata (15 kB)
# Collecting torch>=1.0.0 (from bert_score)
#   Using cached torch-2.7.1-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (29 kB)
# Requirement already satisfied: pandas>=1.0.1 in /opt/nlp-env/lib/python3.11/site-packages (from bert_score) (2.3.1)
# Requirement already satisfied: transformers>=3.0.0 in /opt/nlp-env/lib/python3.11/site-packages (from bert_score) (4.54.0)
# Requirement already satisfied: numpy in /opt/nlp-env/lib/python3.11/site-packages (from bert_score) (2.3.2)
# Requirement already satisfied: requests in /opt/nlp-env/lib/python3.11/site-packages (from bert_score) (2.32.4)
# Requirement already satisfied: tqdm>=4.31.1 in /opt/nlp-env/lib/python3.11/site-packages (from bert_score) (4.67.1)
# Requirement already satisfied: matplotlib in /opt/nlp-env/lib/python3.11/site-packages (from bert_score) (3.10.3)
# Requirement already satisfied: packaging>=20.9 in /opt/nlp-env/lib/python3.11/site-packages (from bert_score) (25.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/nlp-env/lib/python3.11/site-packages (from pandas>=1.0.1->bert_score) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/nlp-env/lib/python3.11/site-packages (from pandas>=1.0.1->bert_score) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /opt/nlp-env/lib/python3.11/site-packages (from pandas>=1.0.1->bert_score) (2025.2)
# Requirement already satisfied: six>=1.5 in /opt/nlp-env/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas>=1.0.1->bert_score) (1.17.0)
# Requirement already satisfied: filelock in /opt/nlp-env/lib/python3.11/site-packages (from torch>=1.0.0->bert_score) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /opt/nlp-env/lib/python3.11/site-packages (from torch>=1.0.0->bert_score) (4.14.1)
# Requirement already satisfied: sympy>=1.13.3 in /opt/nlp-env/lib/python3.11/site-packages (from torch>=1.0.0->bert_score) (1.14.0)
# Requirement already satisfied: networkx in /opt/nlp-env/lib/python3.11/site-packages (from torch>=1.0.0->bert_score) (3.5)
# Requirement already satisfied: jinja2 in /opt/nlp-env/lib/python3.11/site-packages (from torch>=1.0.0->bert_score) (3.1.6)
# Requirement already satisfied: fsspec in /opt/nlp-env/lib/python3.11/site-packages (from torch>=1.0.0->bert_score) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /opt/nlp-env/lib/python3.11/site-packages (from torch>=1.0.0->bert_score) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /opt/nlp-env/lib/python3.11/site-packages (from torch>=1.0.0->bert_score) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /opt/nlp-env/lib/python3.11/site-packages (from torch>=1.0.0->bert_score) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.5.1.17 in /opt/nlp-env/lib/python3.11/site-packages (from torch>=1.0.0->bert_score) (9.5.1.17)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /opt/nlp-env/lib/python3.11/site-packages (from torch>=1.0.0->bert_score) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /opt/nlp-env/lib/python3.11/site-packages (from torch>=1.0.0->bert_score) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /opt/nlp-env/lib/python3.11/site-packages (from torch>=1.0.0->bert_score) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /opt/nlp-env/lib/python3.11/site-packages (from torch>=1.0.0->bert_score) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /opt/nlp-env/lib/python3.11/site-packages (from torch>=1.0.0->bert_score) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.3 in /opt/nlp-env/lib/python3.11/site-packages (from torch>=1.0.0->bert_score) (0.6.3)
# Requirement already satisfied: nvidia-nccl-cu12==2.26.2 in /opt/nlp-env/lib/python3.11/site-packages (from torch>=1.0.0->bert_score) (2.26.2)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /opt/nlp-env/lib/python3.11/site-packages (from torch>=1.0.0->bert_score) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /opt/nlp-env/lib/python3.11/site-packages (from torch>=1.0.0->bert_score) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /opt/nlp-env/lib/python3.11/site-packages (from torch>=1.0.0->bert_score) (1.11.1.6)
# Requirement already satisfied: triton==3.3.1 in /opt/nlp-env/lib/python3.11/site-packages (from torch>=1.0.0->bert_score) (3.3.1)
# Requirement already satisfied: setuptools>=40.8.0 in /opt/nlp-env/lib/python3.11/site-packages (from triton==3.3.1->torch>=1.0.0->bert_score) (80.9.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/nlp-env/lib/python3.11/site-packages (from sympy>=1.13.3->torch>=1.0.0->bert_score) (1.3.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.34.0 in /opt/nlp-env/lib/python3.11/site-packages (from transformers>=3.0.0->bert_score) (0.34.1)
# Requirement already satisfied: pyyaml>=5.1 in /opt/nlp-env/lib/python3.11/site-packages (from transformers>=3.0.0->bert_score) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /opt/nlp-env/lib/python3.11/site-packages (from transformers>=3.0.0->bert_score) (2024.11.6)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /opt/nlp-env/lib/python3.11/site-packages (from transformers>=3.0.0->bert_score) (0.21.2)
# Requirement already satisfied: safetensors>=0.4.3 in /opt/nlp-env/lib/python3.11/site-packages (from transformers>=3.0.0->bert_score) (0.5.3)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /opt/nlp-env/lib/python3.11/site-packages (from huggingface-hub<1.0,>=0.34.0->transformers>=3.0.0->bert_score) (1.1.5)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/nlp-env/lib/python3.11/site-packages (from jinja2->torch>=1.0.0->bert_score) (3.0.2)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/nlp-env/lib/python3.11/site-packages (from matplotlib->bert_score) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /opt/nlp-env/lib/python3.11/site-packages (from matplotlib->bert_score) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/nlp-env/lib/python3.11/site-packages (from matplotlib->bert_score) (4.59.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/nlp-env/lib/python3.11/site-packages (from matplotlib->bert_score) (1.4.8)
# Requirement already satisfied: pillow>=8 in /opt/nlp-env/lib/python3.11/site-packages (from matplotlib->bert_score) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/nlp-env/lib/python3.11/site-packages (from matplotlib->bert_score) (3.2.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/nlp-env/lib/python3.11/site-packages (from requests->bert_score) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/nlp-env/lib/python3.11/site-packages (from requests->bert_score) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/nlp-env/lib/python3.11/site-packages (from requests->bert_score) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/nlp-env/lib/python3.11/site-packages (from requests->bert_score) (2025.7.14)
# Using cached bert_score-0.3.13-py3-none-any.whl (61 kB)
# Using cached torch-2.7.1-cp311-cp311-manylinux_2_28_x86_64.whl (821.2 MB)
# WARNING: Ignoring invalid distribution ~uggingface-hub (/opt/nlp-env/lib/python3.11/site-packages)
# WARNING: Ignoring invalid distribution ~riton (/opt/nlp-env/lib/python3.11/site-packages)
# WARNING: Ignoring invalid distribution ~valuate (/opt/nlp-env/lib/python3.11/site-packages)
# WARNING: Ignoring invalid distribution ~orch (/opt/nlp-env/lib/python3.11/site-packages)
# WARNING: Ignoring invalid distribution ~orchvision (/opt/nlp-env/lib/python3.11/site-packages)
# WARNING: Ignoring invalid distribution ~penai (/opt/nlp-env/lib/python3.11/site-packages)
# WARNING: Ignoring invalid distribution ~ytorch-triton-rocm (/opt/nlp-env/lib/python3.11/site-packages)
# WARNING: Ignoring invalid distribution ~ython-dateutil (/opt/nlp-env/lib/python3.11/site-packages)
# WARNING: Ignoring invalid distribution ~ix (/opt/nlp-env/lib/python3.11/site-packages)
# WARNING: Ignoring invalid distribution ~orchaudio (/opt/nlp-env/lib/python3.11/site-packages)
# Installing collected packages: torch, bert_score
# ERROR: Could not install packages due to an OSError: [Errno 13] Permiso denegado: '/opt/nlp-env/lib/python3.11/site-packages/functorch/_C.cpython-311-x86_64-linux-gnu.so'
# Check the permissions.
#
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/2 [torch]
# WARNING: Ignoring invalid distribution ~uggingface-hub (/opt/nlp-env/lib/python3.11/site-packages)
# WARNING: Ignoring invalid distribution ~riton (/opt/nlp-env/lib/python3.11/site-packages)
# WARNING: Ignoring invalid distribution ~valuate (/opt/nlp-env/lib/python3.11/site-packages)
# WARNING: Ignoring invalid distribution ~orch (/opt/nlp-env/lib/python3.11/site-packages)
# WARNING: Ignoring invalid distribution ~uggingface-hub (/opt/nlp-env/lib/python3.11/site-packages)
# WARNING: Ignoring invalid distribution ~riton (/opt/nlp-env/lib/python3.11/site-packages)
# WARNING: Ignoring invalid distribution ~valuate (/opt/nlp-env/lib/python3.11/site-packages)
# WARNING: Ignoring invalid distribution ~orch (/opt/nlp-env/lib/python3.11/site-packages)
# Note: you may need to restart the kernel to use updated packages.
